# %%
import pandas as pd

# %%
df=pd.read_csv('ewastedataset.csv')

# %%
print(df)
# Out:
#            ItemType      Brand                Model  Yearofmanufacture  \
# 0          Computer       Dell       Latitude E5470               2018
# 1        Smartphone      Apple        iPhone 13 Pro               2022
# 2        Television    Samsung           UN55NU7100               2020
# 3         Microwave         LG            LMC0771BD               2013
# 4    Vacuum cleaner      Dyson            V8 Animal               2021
# 5           Printer         HP  LaserJet Pro M404dn               2019
# 6           Monitor       Dell    UltraSharp U2720Q               2021
# 7    Gaming console       Sony        PlayStation 5               2022
# 8            Camera      Canon        EOS Rebel T7i               2020
# 9            Laptop     Lenovo   ThinkPad X1 Carbon               2021
# 10           Tablet    Samsung        Galaxy Tab S7               2022
# 11     Refrigerator         LG           LFXS26973D               2018
# ...

# %%
df.shape
# Out:
# (28, 13)

# %%
df

# %%
#Prediction parameters
print(df['ItemType'].unique())
print(df['Yearofmanufacture'].unique())
print(df['Condition'].unique())
print(df['RepairPotential'].unique())
print(df['RecyclingPotential'].unique())
print(df['MarketDemand'].unique())
print(df['ActualPrice'].unique())
print(df['RecycledValue'].unique())
# Out:
# ['Computer' 'Smartphone' 'Television' 'Microwave' 'Vacuum cleaner'
#  'Printer' 'Monitor' 'Gaming console' 'Camera' 'Laptop' 'Tablet'
#  'Refrigerator' 'Dishwasher' 'Coffee maker' 'Headphones' 'Blender'
#  'Smartwatch' 'Air conditioner' 'Toaster']
# [2018 2022 2020 2013 2021 2019 2017 2015]
# ['Working']
# ['Yes' 'No']
# ['Yes']
# ['High' 'Medium' 'Low']
# [90000 68400 39600  5760 19440 11520 23040 30240 26640 45720 75600  7560
#   5400 15120 34080  3888  3168]
# [8000 6000 4000  500 2000 1000 2500 2200 7000 3500  450 1400 1800 3200
#   360  280]

# %%
df.isnull().sum()
# Out:
# ItemType              0
# Brand                 0
# Model                 0
# Yearofmanufacture     0
# Condition             0
# Completeness          0
# Datasecurity          0
# RepairPotential       0
# RecyclingPotential    0
# MarketDemand          0
# GeographicLocation    0
# RecycledValue         0
# ActualPrice           0
# dtype: int64

# %%
#Shows the desciption of numerical values
df.describe()
# Out:
#        Yearofmanufacture  RecycledValue   ActualPrice
# count          28.000000      28.000000     28.000000
# mean         2019.785714    2803.214286  31297.714286
# std             2.183391    2205.264834  24377.565143
# min          2013.000000     280.000000   3168.000000
# 25%          2019.000000    1300.000000  14220.000000
# 50%          2020.000000    2100.000000  24840.000000
# 75%          2021.000000    4000.000000  41130.000000
# max          2022.000000    8000.000000  90000.000000

# %%
final_dataset=df[['ItemType','Yearofmanufacture','Condition','RepairPotential','RecyclingPotential','MarketDemand','ActualPrice','RecycledValue']]

# %%
final_dataset.head()
# Out:
#          ItemType  Yearofmanufacture Condition RepairPotential  \
# 0        Computer               2018   Working             Yes
# 1      Smartphone               2022   Working             Yes
# 2      Television               2020   Working             Yes
# 3       Microwave               2013   Working              No
# 4  Vacuum cleaner               2021   Working             Yes
#
#   RecyclingPotential MarketDemand  ActualPrice  RecycledValue
# 0                Yes         High        90000           8000
# 1                Yes         High        68400           6000
# 2                Yes       Medium        39600           4000
# 3                Yes          Low         5760            500
# 4                Yes       Medium        19440           2000

# %%
final_dataset.loc[:, 'CurrentYear'] = 2023
# Out:
# /tmp/ipykernel_1516/818072782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset.loc[:, 'CurrentYear'] = 2023

# %%
final_dataset['Current Year']=2020
# Out:
# /tmp/ipykernel_1516/2574441436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['Current Year']=2020

# %%
final_dataset['CurrentY']=2023

# %%
import pandas as pd

# %%
import pandas as pd

# Assuming df is your original DataFrame
final_dataset = df[['ItemType', 'Yearofmanufacture', 'Condition', 'RepairPotential', 'RecyclingPotential', 'MarketDemand', 'ActualPrice', 'RecycledValue']]

# Add the "CurrentYear" column and initialize it to 2023
final_dataset['CurrentYear'] = 2023

# Display the resulting DataFrame
print(final_dataset)

# %%
final_dataset
# Out:
#            ItemType  Yearofmanufacture Condition RepairPotential  \
# 0          Computer               2018   Working             Yes
# 1        Smartphone               2022   Working             Yes
# 2        Television               2020   Working             Yes
# 3         Microwave               2013   Working              No
# 4    Vacuum cleaner               2021   Working             Yes
# 5           Printer               2019   Working             Yes
# 6           Monitor               2021   Working             Yes
# 7    Gaming console               2022   Working             Yes
# 8            Camera               2020   Working             Yes
# 9            Laptop               2021   Working             Yes
# 10           Tablet               2022   Working             Yes
# 11     Refrigerator               2018   Working              No
# 12       Dishwasher               2019   Working              No
# ...

# %%
final_dataset.head()
# Out:
#          ItemType  Yearofmanufacture Condition RepairPotential  \
# 0        Computer               2018   Working             Yes
# 1      Smartphone               2022   Working             Yes
# 2      Television               2020   Working             Yes
# 3       Microwave               2013   Working              No
# 4  Vacuum cleaner               2021   Working             Yes
#
#   RecyclingPotential MarketDemand  ActualPrice  RecycledValue  CurrentYear  \
# 0                Yes         High        90000           8000         2023
# 1                Yes         High        68400           6000         2023
# 2                Yes       Medium        39600           4000         2023
# 3                Yes          Low         5760            500         2023
# 4                Yes       Medium        19440           2000         2023
#
#    Current Year
# 0          2020
# 1          2020
# 2          2020
# 3          2020
# 4          2020

# %%
import pandas as pd
final_dataset['no_year'] = final_dataset['CurrentYear'] - final_dataset['Yearofmanufacture']
# Out:
# /tmp/ipykernel_1516/3881102680.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset['no_year'] = final_dataset['CurrentYear'] - final_dataset['Yearofmanufacture']

# %%
final_dataset
# Out:
#            ItemType  Yearofmanufacture Condition RepairPotential  \
# 0          Computer               2018   Working             Yes
# 1        Smartphone               2022   Working             Yes
# 2        Television               2020   Working             Yes
# 3         Microwave               2013   Working              No
# 4    Vacuum cleaner               2021   Working             Yes
# 5           Printer               2019   Working             Yes
# 6           Monitor               2021   Working             Yes
# 7    Gaming console               2022   Working             Yes
# 8            Camera               2020   Working             Yes
# 9            Laptop               2021   Working             Yes
# 10           Tablet               2022   Working             Yes
# 11     Refrigerator               2018   Working              No
# 12       Dishwasher               2019   Working              No
# ...

# %%
final_dataset.head()
# Out:
#          ItemType  Yearofmanufacture Condition RepairPotential  \
# 0        Computer               2018   Working             Yes
# 1      Smartphone               2022   Working             Yes
# 2      Television               2020   Working             Yes
# 3       Microwave               2013   Working              No
# 4  Vacuum cleaner               2021   Working             Yes
#
#   RecyclingPotential MarketDemand  ActualPrice  RecycledValue  CurrentYear  \
# 0                Yes         High        90000           8000         2023
# 1                Yes         High        68400           6000         2023
# 2                Yes       Medium        39600           4000         2023
# 3                Yes          Low         5760            500         2023
# 4                Yes       Medium        19440           2000         2023
#
#    Current Year  no_year
# 0          2020        5
# 1          2020        1
# 2          2020        3
# 3          2020       10
# ...

# %%
final_dataset.drop(['Yearofmanufacture'],axis=1,inplace=True)
# Out:
# /tmp/ipykernel_1516/3495074475.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_dataset.drop(['Yearofmanufacture'],axis=1,inplace=True)

# %%
final_dataset
# Out:
#            ItemType Condition RepairPotential RecyclingPotential MarketDemand  \
# 0          Computer   Working             Yes                Yes         High
# 1        Smartphone   Working             Yes                Yes         High
# 2        Television   Working             Yes                Yes       Medium
# 3         Microwave   Working              No                Yes          Low
# 4    Vacuum cleaner   Working             Yes                Yes       Medium
# 5           Printer   Working             Yes                Yes       Medium
# 6           Monitor   Working             Yes                Yes       Medium
# 7    Gaming console   Working             Yes                Yes         High
# 8            Camera   Working             Yes                Yes       Medium
# 9            Laptop   Working             Yes                Yes         High
# 10           Tablet   Working             Yes                Yes         High
# ...

# %%
final_dataset.head()
# Out:
#          ItemType Condition RepairPotential RecyclingPotential MarketDemand  \
# 0        Computer   Working             Yes                Yes         High
# 1      Smartphone   Working             Yes                Yes         High
# 2      Television   Working             Yes                Yes       Medium
# 3       Microwave   Working              No                Yes          Low
# 4  Vacuum cleaner   Working             Yes                Yes       Medium
#
#    ActualPrice  RecycledValue  CurrentYear  Current Year  no_year
# 0        90000           8000         2023          2020        5
# 1        68400           6000         2023          2020        1
# 2        39600           4000         2023          2020        3
# 3         5760            500         2023          2020       10
# 4        19440           2000         2023          2020        2

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head()
# Out:
#    ActualPrice  RecycledValue  CurrentYear  Current Year  no_year  \
# 0        90000           8000         2023          2020        5
# 1        68400           6000         2023          2020        1
# 2        39600           4000         2023          2020        3
# 3         5760            500         2023          2020       10
# 4        19440           2000         2023          2020        2
#
#    ItemType_Blender  ItemType_Camera  ItemType_Coffee maker  \
# 0                 0                0                      0
# 1                 0                0                      0
# 2                 0                0                      0
# 3                 0                0                      0
# 4                 0                0                      0
#
#    ItemType_Computer  ItemType_Dishwasher  ...  ItemType_Refrigerator  \
# 0                  1                    0  ...                      0
# ...

# %%
final_dataset.head()
# Out:
#    ActualPrice  RecycledValue  CurrentYear  Current Year  no_year  \
# 0        90000           8000         2023          2020        5
# 1        68400           6000         2023          2020        1
# 2        39600           4000         2023          2020        3
# 3         5760            500         2023          2020       10
# 4        19440           2000         2023          2020        2
#
#    ItemType_Blender  ItemType_Camera  ItemType_Coffee maker  \
# 0                 0                0                      0
# 1                 0                0                      0
# 2                 0                0                      0
# 3                 0                0                      0
# 4                 0                0                      0
#
#    ItemType_Computer  ItemType_Dishwasher  ...  ItemType_Refrigerator  \
# 0                  1                    0  ...                      0
# ...

# %%
final_dataset=final_dataset.drop(['CurrentYear'],axis=1)

# %%
final_dataset
# Out:
#     ActualPrice  RecycledValue  Current Year  no_year  ItemType_Blender  \
# 0         90000           8000          2020        5                 0
# 1         68400           6000          2020        1                 0
# 2         39600           4000          2020        3                 0
# 3          5760            500          2020       10                 0
# 4         19440           2000          2020        2                 0
# 5         11520           1000          2020        4                 0
# 6         23040           2000          2020        2                 0
# 7         30240           2500          2020        1                 0
# 8         26640           2200          2020        3                 0
# 9         68400           6000          2020        2                 0
# 10        45720           4000          2020        1                 0
# 11        75600           7000          2020        5                 0
# ...

# %%
final_dataset.head()
# Out:
#    ActualPrice  RecycledValue  Current Year  no_year  ItemType_Blender  \
# 0        90000           8000          2020        5                 0
# 1        68400           6000          2020        1                 0
# 2        39600           4000          2020        3                 0
# 3         5760            500          2020       10                 0
# 4        19440           2000          2020        2                 0
#
#    ItemType_Camera  ItemType_Coffee maker  ItemType_Computer  \
# 0                0                      0                  1
# 1                0                      0                  0
# 2                0                      0                  0
# 3                0                      0                  0
# 4                0                      0                  0
#
#    ItemType_Dishwasher  ItemType_Gaming console  ...  ItemType_Refrigerator  \
# 0                    0                        0  ...                      0
# ...

# %%
final_dataset.corr()
# Out:
#                          ActualPrice  RecycledValue  Current Year   no_year  \
# ActualPrice                 1.000000       0.997282           NaN -0.158911
# RecycledValue               0.997282       1.000000           NaN -0.158067
# Current Year                     NaN            NaN           NaN       NaN
# no_year                    -0.158911      -0.158067           NaN  1.000000
# ItemType_Blender           -0.273358      -0.271931           NaN  0.101639
# ItemType_Camera            -0.095674      -0.102872           NaN  0.036959
# ItemType_Coffee maker      -0.190838      -0.204686           NaN -0.108995
# ItemType_Computer           0.471933       0.461838           NaN  0.160286
# ItemType_Dishwasher         0.021113       0.005992           NaN  0.101639
# ItemType_Gaming console     0.009990       0.005992           NaN -0.286436
# ItemType_Headphones        -0.095329      -0.071382           NaN -0.198755
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(final_dataset)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(final_dataset)
plt.savefig("pairplot.png")
plt.show()

# %%
plt.savefig("pairplot.png")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Get correlations of each feature in the dataset
corrmat = df.corr()
top_corr_features = corrmat.index

# Create a figure with a larger size
plt.figure(figsize=(20, 20))

# Plot the heatmap
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")

# Display the heatmap
plt.show()

# %%
X=final_dataset.iloc[:,1:]
y=final_dataset.iloc[:,0]

# %%
### Feature Importance

from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [9.43621572e-01 0.00000000e+00 1.38474592e-03 5.49249283e-06
#  4.70785469e-04 3.45973200e-05 2.71729931e-02 1.92121006e-04
#  3.93970125e-03 9.88494858e-05 1.11205440e-02 5.76754826e-05
#  3.12991319e-04 2.16312563e-04 1.96897218e-03 2.69751524e-03
#  3.42646165e-04 1.63401662e-04 9.80409970e-04 9.72655863e-06
#  1.66928704e-04 4.13297871e-04 4.13387258e-03 4.94847280e-04]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor=RandomForestRegressor()

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)

# %%
import numpy as np

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
print(n_estimators)

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 #Randomized Search CV
#       2
#       3 # Number of trees in random forest
# ----> 4 n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
#       5 # Number of features to consider at every split
#       6 max_features = ['auto', 'sqrt']
#
# NameError: name 'np' is not defined

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 random_grid = {'n_estimators': n_estimators,
#       2                'max_features': max_features,
#       3                'max_depth': max_depth,
#       4                'min_samples_split': min_samples_split,
#       5                'min_samples_leaf': min_samples_leaf}
#       7 print(random_grid)
#
# NameError: name 'n_estimators' is not defined

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)

# %%
rf_random.best_params_

# %%
rf_random.best_score_

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(y_test-predictions)

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metric

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
import pickle

# Re-save the model
with open('re-wired_random_forest_regression_model.pkl', 'wb') as file:
    pickle.dump(rf_random, file)

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
import onnx

# Convert your scikit-learn model to ONNX format
initial_type = [('float_input', FloatTensorType([None, X.shape[1]))]  # Replace X with your input data
onx = convert_sklearn(rf_random, initial_types=initial_type)

# Save the ONNX model to a file
onnx.save_model(onx, "re-wired_random_forest_regression_model.onnx")
print("success")
